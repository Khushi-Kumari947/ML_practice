# %%
import pandas as pd
# from sklearn.ensemble import regress
from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import OneHotEncoder
# from sklearn.pipeline import Pipeline
# from sklearn.compose import ColumnTransformer
# from sklearn.metrics import classification_report, accuracy_score
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('multi_linear_regression.csv')
df.sample(5)
# Out:
#    Experience  Age  Salary
# 2           5   28   45000
# 5          11   40   70000
# 8          18   55  105000
# 7          15   50   95000
# 0           1   22   25000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Experience  10 non-null     int64
#  1   Age         10 non-null     int64
#  2   Salary      10 non-null     int64
# dtypes: int64(3)
# memory usage: 372.0 bytes

# %%
df.isnull().sum()
# Out:
# Experience    0
# Age           0
# Salary        0
# dtype: int64

# %%
sns.heatmap(data=df)
# Out:
# <Axes: >

# %%
# Create subplots (1 row, 3 columns)
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Box plots for each column
axes[0].boxplot(df["Experience"])
axes[0].set_title("Experience")

axes[1].boxplot(df["Age"])
axes[1].set_title("Age")

axes[2].boxplot(df["Salary"])
axes[2].set_title("Salary")

plt.tight_layout()
plt.show()

# %%
df.describe()
# Out:
#        Experience        Age         Salary
# count   10.000000  10.000000      10.000000
# mean    10.200000  39.200000   70500.000000
# std      6.356099  13.019643   30862.598724
# min      1.000000  22.000000   25000.000000
# 25%      5.500000  29.000000   48750.000000
# 50%     10.000000  37.500000   67500.000000
# 75%     14.500000  48.750000   92500.000000
# max     20.000000  60.000000  120000.000000

# %%
sns.pairplot(data=df,height=1.5)
plt.show()

# %%
sns.heatmap(data=df.corr(),annot=True)
plt.show()

# %%
X=df.drop(columns='Salary')
y=df['Salary']

# %%
X.shape,y.shape
# Out:
# ((10, 2), (10,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_test,y_test)*100
# Out:
# 98.17235404455958

# %%
lr.coef_
# Out:
# array([4172.12347989,  313.37698784])

# %%
lr.intercept_
# Out:
# 17296.538821328388
